# %%
import numpy as np

# %%
learning_times = {
    'ItalyPowerDemand': [
        1142.5285668373108,
        1148.6223797798157,
        1143.8703668117523
    ],
    'SonyAIBORobotSurface1': [
        664.0219075679779,
        671.1847152709961,
        665.863046169281
    ],
    'SonyAIBORobotSurface2': [
        893.5407493114471,
        883.3857192993164,
        881.7117714881897
    ],
    'MoteStrain': [
        774.8950781822205,
        757.6399085521698,
        786.5042858123779
    ],
    'TwoLeadECG': [
        765.2673802375793,
        749.631668806076,
        756.0234062671661
    ],
    'ECGFiveDays': [
        829.162668466568,
        829.6388146877289,
        821.647821187973
    ],
    'GunPoint': [
        2611.673372030258,
        2584.751106262207,
        2632.381276845932
    ],
    'DiatomSizeReduction': [
        2394.7850828170776,
        2399.835219860077,
        2392.5950679779053
    ],
    'Coffee': [
        793.2845959663391,
        778.3332047462463,
        811.2495453357697
    ],
    'SyntheticControl': [
        5530.431423187256,
        5387.422071218491,
        5570.727212190628
    ],
    'FaceFour': [
        2478.3527178764343,
        2484.685444831848,
        2490.0236020088196
    ],
    'Symbols': [
        833.6491320133209,
        835.5573263168335,
        841.728812456131
    ],
    'BirdChicken': [
        3229.1473400592804,
        3232.3532469272614
    ]
}

genetic_times = {
    'ItalyPowerDemand': [
        153.45251893997192,
        450.2255733013153,
        97.5090925693512
    ],
    'SonyAIBORobotSurface1': [
        515.1143152713776,
        668.2077238559723,
        836.3047323226929
    ],
    'SonyAIBORobotSurface2': [
        308.1690557003021,
        713.2008895874023,
        853.03835105896
    ],
    'MoteStrain': [
        718.171329498291,
        639.8237974643707,
        731.499746799469
    ],
    'TwoLeadECG': [
        807.30379986763,
        259.80464577674866,
        683.526214838028
    ],
    'ECGFiveDays': [
        2203.8644120693207,
        2199.427417039871,
        2374.2297377586365
    ],
    'GunPoint': [
        4327.696753025055,
        4180.40989279747,
        5149.9298758506775
    ],
    'DiatomSizeReduction': [
        10308.244849920273,
        2350.242351770401,
        9935.893936395645
    ],
    'Coffee': [
        8284.133519887924,
        10021.240044116974,
        4866.812888622284
    ],
    'SyntheticControl': [
        8786.669705867767,
        8033.3005311489105,
        8626.171173334122
    ],
    'FaceFour': [
        10507.636272192001,
        9503.541395425797,
        8967.436970472336
    ],
    'Symbols': [
        10160.754371643066,
        12208.683682441711,
        5042.847385644913
    ],
    'BirdChicken': [
        3913.4592118263245,
        8683.54376244545
    ]
}

# %%
print('\\begin{table}')
print('\t \\centering')
print('\t\\begin{tabular}{c|c|c}')
print('\t\t \\textbf{dataset} & \\textbf{\\textsc{\\texttt{lts}} time} & \\textbf{genetic time} \\\\ \\hline \\hline')
for dataset in learning_times:
    print('\t\t {} & ${}\pm{}$ & ${}\pm{}$ \\\\ \\hline'.format(
        dataset, 
        np.around(np.mean(learning_times[dataset]), 5),
        np.around(np.std(learning_times[dataset]), 2),
        np.around(np.mean(genetic_times[dataset]), 5),
        np.around(np.std(genetic_times[dataset]), 2),
    ))
    
print('\t\\end{tabular}')
print('\\caption{The runtime of the genetic and \\textsc{\\texttt{lts}} algorithm on 21 datasets}')
print('\\label{tbl:runtimes}')
print('\\end{table}')
# Out:
# \begin{table}
# 	\begin{tabular}{c|c|c}
# 		 \textbf{dataset} & \textbf{\textsc{\texttt{lts}} time} & \textbf{genetic time} \\ \hline \hline
# 		 ItalyPowerDemand & $1145.0071\pm2.61$ & $233.72906\pm154.78$ \\ \hline
# 		 SonyAIBORobotSurface1 & $667.02322\pm3.04$ & $673.20892\pm131.17$ \\ \hline
# 		 SonyAIBORobotSurface2 & $886.21275\pm5.23$ & $624.80277\pm231.06$ \\ \hline
# 		 MoteStrain & $773.01309\pm11.86$ & $696.49829\pm40.44$ \\ \hline
# 		 TwoLeadECG & $756.97415\pm6.42$ & $583.54489\pm234.43$ \\ \hline
# 		 ECGFiveDays & $826.81643\pm3.66$ & $2259.17386\pm81.38$ \\ \hline
# 		 GunPoint & $2609.60192\pm19.5$ & $4552.67884\pm426.58$ \\ \hline
# 		 DiatomSizeReduction & $2395.73846\pm3.03$ & $7531.46038\pm3666.83$ \\ \hline
# 		 Coffee & $794.28912\pm13.46$ & $7724.06215\pm2141.23$ \\ \hline
# 		 SyntheticControl & $5496.19357\pm78.65$ & $8482.04714\pm324.01$ \\ \hline
# 		 FaceFour & $2484.35392\pm4.77$ & $9659.53821\pm638.39$ \\ \hline
# ...
